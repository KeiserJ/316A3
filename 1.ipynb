# %%
import pandas as pd
df = pd.read_csv('DATA/Gravity_V202211.csv')
df_2019 = df[df['year'] == 2019]
df_2019.to_csv('DATA/Gravity_2019.csv', index=False)
# Out:
# /var/folders/pp/hkpk05n1737_pqqqk3vw1s8c0000gn/T/ipykernel_60302/1449936979.py:2: DtypeWarning: Columns (40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('DATA/Gravity_V202211.csv')
